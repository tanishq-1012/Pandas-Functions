# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/tanishqsharma/Desktop/Python Projects/Files/Companies.csv')
df
# Out:
#     Unnamed: 0 Unnamed: 1                           Unnamed: 2  \
# 0        Index       Rank                                 Name
# 1            0          1                              Walmart
# 2            1          2                               Amazon
# 3            2          3                                Apple
# 4            3          4                   UnitedHealth Group
# 5            4          5                   Berkshire Hathaway
# 6            5          6                           CVS Health
# 7            6          7                           ExxonMobil
# 8            7          8                             Alphabet
# 9            8          9                 McKesson Corporation
# 10           9         10                              Cencora
# 11          10         11                               Costco
# 12          11         12                       JPMorgan Chase
# 13          12         13                            Microsoft
# ...

# %%
df2 = pd.read_excel(r'/Users/tanishqsharma/Desktop/Random Folder/xlsx files/ITPS NEW RATES DT-01-06-23.xlsx')
df2
# Out:
#    ITPS (LP) rates wef 01-06-2023                 Unnamed: 1  \
# 0                           SL NO                DESTINATION
# 1                               1                     Aruba
# 2                               2                 Australia
# 3                               3                   Belarus
# 4                               4                    Bhutan
# 5                               5                  Cambodia
# 6                               6                     Chile
# 7                               7                     China
# 8                               8                   Curacao
# 9                              10                      Egypt
# 10                             11                   Estonia
# 11                             12                     France
# 12                             13                   Georgia
# 13                             14                    Germany
# 14                             15                 Gibraltar
# ...

# %%
pd.set_option('display.max.rows',102)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ITPS (LP) rates wef 01-06-2023  41 non-null     object
#  1   Unnamed: 1                      41 non-null     object
#  2   Unnamed: 2                      41 non-null     object
#  3   Unnamed: 3                      41 non-null     object
# dtypes: object(4)
# memory usage: 1.4+ KB
